# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df_players=pd.read_csv('C:/Users/shadw/Downloads/archive (1)/football_players.csv')

# %%
df_players.head()
# Out:
#    Rank    Origin             Player From(Country)       From(Club)  \
# 0     1    Brazil             Neymar         Spain        Barcelona
# 1     2    France      Kylian Mbappé        France           Monaco
# 2     3    Brazil  Philippe Coutinho       England        Liverpool
# 3     4  Portugal         João Félix      Portugal          Benfica
# 4     5    France  Antoine Griezmann         Spain  Atlético Madrid
#
#   To(Country)             To(Club)    Position  Fee(€ mln) Fee(£ mln)  Year  \
# 0      France  Paris Saint-Germain     Forward       222.0       £198  2017
# 1      France  Paris Saint-Germain     Forward       180.0       £163  2018
# 2       Spain            Barcelona  Midfielder       145.0       £105  2018
# 3       Spain      Atlético Madrid     Forward       126.0     £104.1  2019
# 4       Spain            Barcelona     Forward       120.0       £107  2019
#
#    Born
# 0  1992
# 1  1998
# 2  1992
# 3  1999
# 4  1991

# %%
df_players['From(Country)'].unique()
# Out:
# array(['Spain', 'France', 'England', 'Portugal', 'Italy', 'Germany',
#        'Netherlands'], dtype=object)

# %%
sns.countplot('From(Country)',data=df_players)
# Out:
# C:\Users\shadw\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='From(Country)', ylabel='count'>

# %%
df_players[df_players["From(Country)"] == "Spain"]
# Out:
#     Rank     Origin             Player From(Country)       From(Club)  \
# 0      1     Brazil             Neymar         Spain        Barcelona
# 4      5     France  Antoine Griezmann         Spain  Atlético Madrid
# 9     10   Portugal  Cristiano Ronaldo         Spain      Real Madrid
# 18    19      Spain  Kepa Arrizabalaga         Spain  Athletic Bilbao
# 20    21     France    Lucas Hernandez         Spain  Atlético Madrid
# 24    25  Argentina     Ángel Di María         Spain      Real Madrid
# 29    30     Brazil             Arthur         Spain        Barcelona
# 30    31      Spain              Rodri         Spain  Atlético Madrid
# 37    38      Spain      Álvaro Morata         Spain      Real Madrid
# 38    39     France    Aymeric Laporte         Spain  Athletic Bilbao
# 46    47   Portugal          Luís Figo         Spain        Barcelona
# 52    53   Colombia     Radamel Falcao         Spain  Atlético Madrid
#
#    To(Country)             To(Club)    Position  Fee(€ mln) Fee(£ mln)  Year  \
# 0       France  Paris Saint-Germain     Forward       222.0       £198  2017
# 4        Spain            Barcelona     Forward       120.0       £107  2019
# 9        Italy             Juventus     Forward       100.0        £88  2018
# 18     England              Chelsea  Goalkeeper        80.0      £71.6  2018
# 20     Germany        Bayern Munich    Defender        80.0        £68  2019
# 24     England    Manchester United  Midfielder        75.6      £59.7  2014
# 29       Italy             Juventus  Midfielder        72.0        £66  2020
# 30     England      Manchester City  Midfielder        70.0        £63  2019
# 37     England              Chelsea     Striker        65.5        £58  2017
# 38     England      Manchester City    Defender        65.2        £57  2018
# 46       Spain          Real Madrid  Midfielder        62.0        £37  2000
# 52      France               Monaco     Striker        60.0        £51  2013
#
#     Born
# 0   1992
# 4   1991
# 9   1985
# 18  1994
# 20  1996
# 24  1988
# 29  1996
# 30  1996
# 37  1992
# 38  1994
# 46  1972
# 52  1986
